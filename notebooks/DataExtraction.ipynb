# %%
# QUERY CONFIGURATION

import os
from dotenv import load_dotenv

# Load variables from the .env file
load_dotenv()

# Get the API Key from the environment variable
API_KEY = os.getenv("YOUTUBE_API_KEY")

# Input parameters that can be modified
config = {
    "query": "colombia elecciones 2026",
    "published_after": "2025-03-01T00:00:00Z",
    "published_before": "2026-03-09T23:59:59Z",
    "min_views": 10000,
    "min_comments": 20,
    "max_comments": 10000, # Max number of comments to read
    "max_results": 2000  #  Max number of results to fetch
}

# %%
# Function to search YouTube videos based on the configuration

import requests
from datetime import datetime

def search_videos():
    videos = []
    next_page_token = None

    while len(videos) < config["max_results"]:
        print(f"Buscando videos... ({len(videos)}/{config['max_results']})")
        
        url = "https://www.googleapis.com/youtube/v3/search"
        params = {
            "part": "snippet",
            "q": config["query"],
            "type": "video",
            "order": "date",
            "publishedAfter": config["published_after"],
            "publishedBefore": config["published_before"],
            "maxResults": 50,  # Max results per request
            "key": API_KEY
        }
        if next_page_token:
            params["pageToken"] = next_page_token

        response = requests.get(url, params=params)
        data = response.json()

        # Check for errors in the response
        video_ids = [item["id"]["videoId"] for item in data.get("items", [])]
        if not video_ids:
            break

        # Fetch video details for the found video IDs
        details = get_video_details(video_ids)
        for video in details:
            views = int(video.get("statistics", {}).get("viewCount", 0))
            comments = int(video.get("statistics", {}).get("commentCount", 0))
            if views >= config["min_views"] and comments >= config["min_comments"]:
                videos.append(video)
                if len(videos) >= config["max_results"]:
                    break

        next_page_token = data.get("nextPageToken")
        if not next_page_token:
            break

    print(f"Total de videos encontrados que cumplen filtros: {len(videos)}")
    return videos

def get_video_details(video_ids):
    url = "https://www.googleapis.com/youtube/v3/videos"
    params = {
        "part": "snippet,statistics,contentDetails",
        "id": ",".join(video_ids),
        "key": API_KEY
    }

    response = requests.get(url, params=params)
    return response.json().get("items", [])

# %%
# Direct search test and display of video titles
videos = search_videos()
for v in videos[:3]:  # Display only the first 3 videos
    print("Video:", v["snippet"]["title"])
# Out:
# Buscando videos... (0/2000)
# Buscando videos... (31/2000)
# Buscando videos... (59/2000)
# Total de videos encontrados que cumplen filtros: 82
# Video: Elecciones en Colombia: Petro Resiste, Cepeda Avanza y la Derecha Busca Reaccionar
# Video: Elecciones 8 de marzo: quién ganó, cómo quedó el Congreso y qué viene para las presidenciales
# Video: 📊 Nuevo Senado queda fragmentado tras elecciones de 2026

# %%
# PRELIMINARY STORAGE OF VIDEO FILE
import pandas as pd
from isodate import parse_duration
import os

def save_videos_to_csv(videos, output_path="../data/videos_preliminares.csv"):
    os.makedirs("data", exist_ok=True)

    rows = []
    for v in videos:
        stats = v.get("statistics", {})
        snippet = v.get("snippet", {})
        content = v.get("contentDetails", {})
        rows.append({
            "video_id": v["id"],
            "title": snippet.get("title"),
            "publishedAt": snippet.get("publishedAt"),
            "channel_id": snippet.get("channelId"),
            "channel_title": snippet.get("channelTitle"),
            "views": stats.get("viewCount"),
            "likes": stats.get("likeCount"),
            #"dilikes": stats.get("dilikeCount"), No disponible en la API
            #"favorite": stats.get("favoriteCount"), No disponible en la API
            "comments": stats.get("commentCount"),
            "description": snippet.get("description"),
            "video_tags": ", ".join(snippet.get("tags", [])),
            "duration_seconds" : int(parse_duration(content.get("duration")).total_seconds()),
            #"video_category": snippet.get("categoryId"),
            #"default_audio_language": snippet.get("defaultAudioLanguage"),
            "video_url": f"https://www.youtube.com/watch?v={v['id']}"
        })

    df = pd.DataFrame(rows)
    df_sind = df.drop_duplicates()
    if(df.shape[0]>df_sind.shape[0]):
        print(f"Se encontraron {df.shape[0]-df_sind.shape[0]} videos duplicados. Los duplicados fueron removidos.")
        
    df_sind.to_csv(output_path, index=False)
    print(f"Videos preliminares guardados en: {output_path}")

# If run directly, execute the search and save the results
save_videos_to_csv(videos)
# Out:
# Videos preliminares guardados en: ../data/videos_preliminares.csv

# %%
# ADDITION OF CHANNEL METADATA

def get_channel_metadata(channel_ids):
    channel_info = {}
    for chunk in chunks(channel_ids, 50):  # API allows 50 IDs per request
        url = "https://www.googleapis.com/youtube/v3/channels"
        params = {
            "part": "snippet,statistics",
            "id": ",".join(chunk),
            "key": API_KEY
        }
        res = requests.get(url, params=params).json()
        for item in res.get("items", []):
            channel_info[item["id"]] = {
                "channel_subscribers": item["statistics"].get("subscriberCount"),
                "channel_country": item["snippet"].get("country")
            }
    return channel_info



def chunks(lst, n):
    """Split the list into chunks of at most n elements."""
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

def enrich_video_data(input_csv="../data/videos_preliminares.csv"):
    df = pd.read_csv(input_csv)
    
    print("Obteniendo metadatos de canales...")
    channel_data = get_channel_metadata(df["channel_id"].unique().tolist())

    # Add to the DataFrame
    df["channel_subscribers"] = df["channel_id"].map(lambda x: channel_data.get(x, {}).get("channel_subscribers"))
    df["channel_country"] = df["channel_id"].map(lambda x: channel_data.get(x, {}).get("channel_country"))

    df.to_csv(input_csv, index=False)
    print(f"Archivo actualizado con metadatos enriquecidos: {input_csv}")


enrich_video_data()
# Out:
# Obteniendo metadatos de canales...
# Archivo actualizado con metadatos enriquecidos: ../data/videos_preliminares.csv

# %%
# GET COMMENTS

def get_comments_for_video(video_id, max_comments=100):
    comments = []
    next_page_token = None

    while len(comments) < max_comments:
        url = "https://www.googleapis.com/youtube/v3/commentThreads"
        params = {
            "part": "snippet,replies",
            "videoId": video_id,
            "maxResults": 100,
            "textFormat": "plainText",
            "key": API_KEY
        }
        if next_page_token:
            params["pageToken"] = next_page_token

        response = requests.get(url, params=params)
        data = response.json()

        for item in data.get("items", []):
            comment = item["snippet"]["topLevelComment"]["snippet"]
            comment_data = {
                "video_id": video_id,
                "comment_id": item["snippet"]["topLevelComment"]["id"],
                "text": comment["textDisplay"],
                "author_name": comment["authorDisplayName"],
                "author_id": item["snippet"]["topLevelComment"]["snippet"]["authorChannelId"]["value"],
                "published_at": comment["publishedAt"],
                "likes": comment["likeCount"],
                "is_reply": False,
                "reply_to_comment_id": None
            }
            comments.append(comment_data)

            # If there are replies, capture those as well
            if "replies" in item:
                for reply in item["replies"]["comments"]:
                    reply_data = reply["snippet"]
                    comments.append({
                        "video_id": video_id,
                        "comment_id": reply["id"],
                        "text": reply_data["textDisplay"],
                        "author_name": reply_data["authorDisplayName"],
                        "author_id": reply["snippet"]["authorChannelId"]["value"],
                        "published_at": reply_data["publishedAt"],
                        "likes": reply_data["likeCount"],
                        "is_reply": True,
                        "reply_to_comment_id": item["snippet"]["topLevelComment"]["id"]
                    })

        next_page_token = data.get("nextPageToken")
        if not next_page_token:
            break

    return comments

def get_all_comments(video_ids, max_comments=100):
    all_comments = []
    count = 1
    for video_id in video_ids:
        print(f"Obteniendo comentarios para el video ({count}): {video_id}")
        comments = get_comments_for_video(video_id, max_comments)
        all_comments.extend(comments)
        count += 1
    return all_comments

def save_comments_to_csv(comments, output_path="../data/comments.csv"):
    df = pd.DataFrame(comments)
    df.to_csv(output_path, index=False)
    print(f"Comentarios guardados en: {output_path}")


# Load video IDs from the preliminary videos CSV
videos_df = pd.read_csv("../data/videos_preliminares.csv")
video_ids = videos_df["video_id"].tolist()

# Get comments for all videos
comments = get_all_comments(video_ids, max_comments = config["max_comments"])

# Save comments to CSV
save_comments_to_csv(comments)
# Out:
# Obteniendo comentarios para el video (1): rrwt3A0DU5w
# Obteniendo comentarios para el video (2): 5whjYnejV_k
# Obteniendo comentarios para el video (3): 3KhEg8P9KiU
# Obteniendo comentarios para el video (4): Yd2u3VgjRdI
# Obteniendo comentarios para el video (5): 5qg1qANHzx8
# Obteniendo comentarios para el video (6): VPxjOwYLZKY
# Obteniendo comentarios para el video (7): uiiW06KHMi0
# Obteniendo comentarios para el video (8): Hazlw-UMszU
# Obteniendo comentarios para el video (9): Nqg84vnwklI
# Obteniendo comentarios para el video (10): HEVMLtZMFco
# Obteniendo comentarios para el video (11): sfKCXLeJBME
# Obteniendo comentarios para el video (12): 3q8Fxjl-qdM
# Obteniendo comentarios para el video (13): Y86V7_ZcPVw
# Obteniendo comentarios para el video (14): hkLfI0ruYFI
# Obteniendo comentarios para el video (15): UyKOv9Co9B8
# Obteniendo comentarios para el video (16): QeUnrFieJGo
# Obteniendo comentarios para el video (17): 6Cj4e_skLGw
# Obteniendo comentarios para el video (18): XxBeHoBD-oU
# Obteniendo comentarios para el video (19): Rmreg4vOTPg
# Obteniendo comentarios para el video (20): Xa4AxYjVIEI
# Obteniendo comentarios para el video (21): 7esH438IBX8
# Obteniendo comentarios para el video (22): YcZXeVFxVJo
# Obteniendo comentarios para el video (23): umxh2KJSBbo
# Obteniendo comentarios para el video (24): poMS0txMBjo
# Obteniendo comentarios para el video (25): ROWXFVr1hPM
# Obteniendo comentarios para el video (26): rtFfztq1L7A
# Obteniendo comentarios para el video (27): R8DwLj3M8y4
# Obteniendo comentarios para el video (28): Ao2iS2jblVQ
# Obteniendo comentarios para el video (29): EEEnDFdHZ1k
# Obteniendo comentarios para el video (30): JJ73s_XWRmk
# Obteniendo comentarios para el video (31): N0vswT_gp5g
# Obteniendo comentarios para el video (32): BK9hZ8X4is4
# Obteniendo comentarios para el video (33): _407IbsJfjc
# Obteniendo comentarios para el video (34): cXN7ZgrpGXU
# Obteniendo comentarios para el video (35): emBkqJwXeW4
# Obteniendo comentarios para el video (36): d1-cNeowIds
# Obteniendo comentarios para el video (37): Hg6UxDHCMVI
# Obteniendo comentarios para el video (38): ouGTdHk8CfY
# Obteniendo comentarios para el video (39): Al3eme2cw48
# Obteniendo comentarios para el video (40): P893B_dlwho
# Obteniendo comentarios para el video (41): x2LZVBrTdnI
# Obteniendo comentarios para el video (42): vKyls3jTtaI
# Obteniendo comentarios para el video (43): -PROq0SRvTE
# Obteniendo comentarios para el video (44): l1-wQQzSdlI
# Obteniendo comentarios para el video (45): Md2e_kvxA3U
# Obteniendo comentarios para el video (46): jFrvqq3ZX50
# Obteniendo comentarios para el video (47): Vrf9loinLBw
# Obteniendo comentarios para el video (48): JWlNajLtP68
# Obteniendo comentarios para el video (49): f8R2Ldw7A24
# Obteniendo comentarios para el video (50): 1omdkx7fPMs
# Obteniendo comentarios para el video (51): PNwekTEDeRM
# Obteniendo comentarios para el video (52): ypPXq-exDnY
# Obteniendo comentarios para el video (53): FNlFKdENoMc
# Obteniendo comentarios para el video (54): ibssSpbU3lI
# Obteniendo comentarios para el video (55): uoGvkg80Hps
# Obteniendo comentarios para el video (56): tSQKpJhrbeY
# Obteniendo comentarios para el video (57): GkaiXr0PWdM
# Obteniendo comentarios para el video (58): frexi_qd9IM
# Obteniendo comentarios para el video (59): B1XX7fvjicA
# Obteniendo comentarios para el video (60): o1Dn0w-KLCI
# Obteniendo comentarios para el video (61): XmAk12QHW6I
# Obteniendo comentarios para el video (62): IS9QOxEbp9E
# Obteniendo comentarios para el video (63): nyW5lKoZBnk
# Obteniendo comentarios para el video (64): blFJbJMJJi8
# Obteniendo comentarios para el video (65): fXKqLxjYbB0
# Obteniendo comentarios para el video (66): Ytly1_k4fmo
# Obteniendo comentarios para el video (67): cyLQZh9pFM0
# Obteniendo comentarios para el video (68): FJDHuDDYR6o
# Obteniendo comentarios para el video (69): c5SZAm_oLdA
# Obteniendo comentarios para el video (70): PxzxjDtH48k
# Obteniendo comentarios para el video (71): 9dQ12_6Rr4k
# Obteniendo comentarios para el video (72): etHyfBjomy0
# Obteniendo comentarios para el video (73): LG-BnFN8aYE
# Obteniendo comentarios para el video (74): hirkO-c-r5g
# Obteniendo comentarios para el video (75): e5moZAblyx0
# Obteniendo comentarios para el video (76): qCOxjhOdfKk
# Obteniendo comentarios para el video (77): NpyZ5Gp_QJk
# Obteniendo comentarios para el video (78): E8JZxfbAjv4
# Obteniendo comentarios para el video (79): 9TIyx9iqh2I
# Obteniendo comentarios para el video (80): dz2JlHm1EIk
# Obteniendo comentarios para el video (81): 0SB2M7To7D0
# Obteniendo comentarios para el video (82): 3E2MgHo3BM0
# Comentarios guardados en: ../data/comments.csv
